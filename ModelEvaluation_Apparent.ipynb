# %%
from model_evaluation import perform_apparent_model_evaluation
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
perform_apparent_model_evaluation('crp', 'etanercept', outcome_col = 'class_poor')
# Out:
# 2021-07-15 23:53:58,675;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: etanercept - outcome_col: class_poor - _type: log
# 2021-07-15 23:53:58,682;INFO - Created output directories
# 2021-07-15 23:59:04,027;INFO - {'acc_measure_values': array([0.14011718, 0.1403806 , 0.13997465, 0.14010072, 0.14047598,
#        0.14021871, 0.14004986, 0.13971961, 0.14042567, 0.14006683,
#        0.14008926, 0.13958964, 0.13964092, 0.14001227, 0.13991367,
#        0.13996534, 0.14033689, 0.1400103 , 0.13958031, 0.13976524]), 'acc_measure': 0.14003106285709244, 'acc_measure_iqr': 0.0002659983525418741, 'auc_values': array([0.7024453 , 0.6994852 , 0.7039897 , 0.70272415, 0.69850922,
#        0.70181253, 0.70208065, 0.70637066, 0.69891677, 0.70233805,
#        0.70242385, 0.70515873, 0.70598456, 0.70311025, 0.70348563,
# ...

# %%
perform_apparent_model_evaluation('esr', 'etanercept', outcome_col = 'class_poor')
# Out:
# 2021-07-15 23:59:04,062;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: etanercept - outcome_col: class_poor - _type: log
# 2021-07-15 23:59:04,065;INFO - Created output directories
# 2021-07-16 00:02:52,391;INFO - {'acc_measure_values': array([0.14743724, 0.14701354, 0.14732562, 0.14716828, 0.14778586,
#        0.14770873, 0.14742794, 0.14771967, 0.14706097, 0.14718512,
#        0.14777542, 0.14713862, 0.14710703, 0.14745521, 0.14747395,
#        0.14740753, 0.14743553, 0.14684955, 0.14750652, 0.14771192]), 'acc_measure': 0.14743173441913865, 'acc_measure_iqr': 0.00039620710748250465, 'auc_values': array([0.71736809, 0.71759695, 0.71624921, 0.71792753, 0.71468531,
#        0.71542276, 0.7165035 , 0.71579148, 0.71841068, 0.71783853,
#        0.71472346, 0.71777495, 0.71806739, 0.7158042 , 0.71612206,
# ...

# %%
perform_apparent_model_evaluation('esr', 'adalimumab', outcome_col = 'class_poor')
# Out:
# 2021-07-16 00:02:52,425;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: adalimumab - outcome_col: class_poor - _type: log
# 2021-07-16 00:02:52,430;INFO - Created output directories
# 2021-07-16 00:06:15,789;INFO - {'acc_measure_values': array([0.13374344, 0.13349814, 0.13390914, 0.13352923, 0.13432481,
#        0.13429891, 0.13433884, 0.1342562 , 0.13450865, 0.13411493,
#        0.13414113, 0.13334677, 0.13374061, 0.13406641, 0.13433315,
#        0.13325272, 0.13380083, 0.13413673, 0.13413336, 0.13354253]), 'acc_measure': 0.1340906716944757, 'acc_measure_iqr': 0.0005757852090152171, 'auc_values': array([0.78130996, 0.78113553, 0.78139717, 0.78174603, 0.77873714,
#        0.77926042, 0.77943485, 0.77834467, 0.77895517, 0.77939124,
#        0.77899878, 0.78139717, 0.78056864, 0.78000174, 0.77969649,
# ...

# %%
perform_apparent_model_evaluation('crp', 'adalimumab', outcome_col = 'class_poor')
# Out:
# 2021-07-16 00:06:15,816;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: adalimumab - outcome_col: class_poor - _type: log
# 2021-07-16 00:06:15,819;INFO - Created output directories
# 2021-07-16 00:09:05,727;INFO - {'acc_measure_values': array([0.12702162, 0.12716759, 0.1270311 , 0.12692368, 0.12700283,
#        0.12693551, 0.1270809 , 0.12689369, 0.12703641, 0.12685405,
#        0.12699305, 0.12704962, 0.12701975, 0.12691558, 0.12688385,
#        0.12691134, 0.12692235, 0.1273044 , 0.12700351, 0.12672415]), 'acc_measure': 0.12699793642618046, 'acc_measure_iqr': 0.00011790754671930914, 'auc_values': array([0.74596177, 0.74444945, 0.74599395, 0.74728103, 0.74638008,
#        0.74618701, 0.74657314, 0.74692709, 0.74518952, 0.74612266,
#        0.7459296 , 0.74515735, 0.7463479 , 0.74641225, 0.74721668,
# ...

# %%
perform_apparent_model_evaluation('crp', 'adalimumab', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-16 00:09:05,751;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: adalimumab - outcome_col: class - _type: mnlog
# 2021-07-16 00:09:05,763;INFO - Created output directories
# 2021-07-16 00:11:58,370;INFO - {'acc_measure_values': array([0.56616052, 0.57483731, 0.56399132, 0.56832972, 0.56616052,
#        0.57483731, 0.56616052, 0.57700651, 0.57049892, 0.57266811,
#        0.56616052, 0.57483731, 0.56832972, 0.57266811, 0.56399132,
#        0.5791757 , 0.56832972, 0.57483731, 0.57266811, 0.57266811]), 'acc_measure': 0.5715835140997831, 'acc_measure_iqr': 0.008676789587852451, 'auc_values': array([0.71299607, 0.71500424, 0.71314965, 0.71408   , 0.71305383,
#        0.71392098, 0.71381751, 0.71561943, 0.71269042, 0.71428207,
#        0.71318595, 0.71358192, 0.71337278, 0.71406794, 0.71326694,
# ...

# %%
perform_apparent_model_evaluation('esr', 'adalimumab', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-16 00:11:58,411;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: adalimumab - outcome_col: class - _type: mnlog
# 2021-07-16 00:11:58,413;INFO - Created output directories
# 2021-07-16 00:15:29,366;INFO - {'acc_measure_values': array([0.58333333, 0.57795699, 0.58064516, 0.58333333, 0.58602151,
#        0.58602151, 0.58870968, 0.58870968, 0.58333333, 0.57795699,
#        0.57795699, 0.58870968, 0.58602151, 0.57795699, 0.58870968,
#        0.58870968, 0.58602151, 0.58870968, 0.57526882, 0.57795699]), 'acc_measure': 0.5846774193548387, 'acc_measure_iqr': 0.010752688172043001, 'auc_values': array([0.74324987, 0.74367239, 0.74229958, 0.74281249, 0.74264039,
#        0.74469325, 0.74530459, 0.74381045, 0.74455675, 0.74323811,
#        0.74213986, 0.74531512, 0.74462825, 0.7441141 , 0.74516035,
# ...

# %%
perform_apparent_model_evaluation('crp', 'etanercept', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-16 00:19:54,545;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: etanercept - outcome_col: class - _type: mnlog
# 2021-07-16 00:19:54,553;INFO - Created output directories
# 2021-07-16 00:24:26,104;INFO - {'acc_measure_values': array([0.54113111, 0.53856041, 0.54113111, 0.53856041, 0.54241645,
#        0.54113111, 0.54241645, 0.54113111, 0.54241645, 0.54113111,
#        0.54241645, 0.54241645, 0.54241645, 0.54113111, 0.54498715,
#        0.53984576, 0.54241645, 0.53984576, 0.5437018 , 0.5437018 ]), 'acc_measure': 0.5417737789203085, 'acc_measure_iqr': 0.0012853470437018677, 'auc_values': array([0.6933136 , 0.69187993, 0.69208753, 0.69175549, 0.69429694,
#        0.69431186, 0.69343096, 0.6928731 , 0.69307326, 0.69277908,
#        0.69323968, 0.69308697, 0.69408005, 0.69408461, 0.6929176 ,
# ...

# %%
perform_apparent_model_evaluation('esr', 'etanercept', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-16 00:24:26,151;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: etanercept - outcome_col: class - _type: mnlog
# 2021-07-16 00:24:26,154;INFO - Created output directories
# 2021-07-16 00:28:07,295;INFO - {'acc_measure_values': array([0.54834055, 0.54401154, 0.54256854, 0.54689755, 0.54834055,
#        0.54834055, 0.54256854, 0.54834055, 0.54689755, 0.54256854,
#        0.54401154, 0.54256854, 0.54834055, 0.54834055, 0.54256854,
#        0.54834055, 0.54834055, 0.54256854, 0.54256854, 0.54834055]), 'acc_measure': 0.5468975468975469, 'acc_measure_iqr': 0.005772005772005762, 'auc_values': array([0.70467519, 0.70515943, 0.70452132, 0.70466026, 0.70533512,
#        0.70343761, 0.70595988, 0.70423612, 0.70590208, 0.70471342,
#        0.70491213, 0.7044984 , 0.70442069, 0.70345769, 0.70436556,
# ...

# %%
perform_apparent_model_evaluation('crp', 'eta_ada', outcome_col = 'class_poor')
# Out:
# 2021-07-27 09:52:44,076;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: eta_ada - outcome_col: class_poor - _type: log
# 2021-07-27 09:52:44,097;INFO - Created output directories
# 2021-07-27 09:56:52,106;INFO - {'acc_measure_values': array([0.14109981, 0.14105704, 0.14091251, 0.14113609, 0.14107262,
#        0.14101763, 0.14108026, 0.1410734 , 0.1410105 , 0.14090952,
#        0.14092818, 0.14107876, 0.14099004, 0.14098649, 0.14088421,
#        0.14104994, 0.14109963, 0.14109652, 0.14107467, 0.14098611]), 'acc_measure': 0.14105348927232364, 'acc_measure_iqr': 9.274320142266257e-05, 'auc_values': array([0.67925626, 0.67984229, 0.68141078, 0.67901495, 0.67964407,
#        0.67988538, 0.67953635, 0.67951049, 0.68030336, 0.68144956,
#        0.6812298 , 0.67952773, 0.68069117, 0.6802775 , 0.68152282,
# ...

# %%
perform_apparent_model_evaluation('esr', 'eta_ada', outcome_col = 'class_poor')
# Out:
# 2021-07-27 09:56:52,131;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: eta_ada - outcome_col: class_poor - _type: log
# 2021-07-27 09:56:52,134;INFO - Created output directories
# 2021-07-27 10:01:21,875;INFO - {'acc_measure_values': array([0.14772259, 0.14758946, 0.14759051, 0.1477866 , 0.14773556,
#        0.14736598, 0.14765144, 0.14787074, 0.14734994, 0.14767959,
#        0.14779735, 0.14770934, 0.14791781, 0.14757449, 0.1473448 ,
#        0.14754692, 0.14746147, 0.14783927, 0.14729653, 0.14774785]), 'acc_measure': 0.1476655151034759, 'acc_measure_iqr': 0.00023197554898035655, 'auc_values': array([0.70779296, 0.70883303, 0.70901897, 0.70750825, 0.70788593,
#        0.71074467, 0.70813578, 0.70724097, 0.71079696, 0.70826942,
#        0.70727583, 0.708037  , 0.70627644, 0.70862967, 0.71090155,
# ...

# %%
perform_apparent_model_evaluation('crp', 'TNFi', outcome_col = 'class_poor')
# Out:
# 2021-07-27 14:15:42,763;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: TNFi - outcome_col: class_poor - _type: log
# 2021-07-27 14:15:42,784;INFO - Created output directories
# 2021-07-27 14:19:24,232;INFO - {'acc_measure_values': array([0.1463792 , 0.14621913, 0.14632554, 0.14639389, 0.14631037,
#        0.14620112, 0.14624833, 0.14637448, 0.14633089, 0.14637959,
#        0.14631691, 0.14637434, 0.14622529, 0.1461738 , 0.14641762,
#        0.14635384, 0.14617065, 0.14629015, 0.1462474 , 0.14630732]), 'acc_measure': 0.14631364062610258, 'acc_measure_iqr': 0.00013250651350196763, 'auc_values': array([0.6771177 , 0.67868411, 0.6776539 , 0.67704819, 0.67766632,
#        0.67890008, 0.67832168, 0.67717231, 0.67773582, 0.67718224,
#        0.67774575, 0.67713011, 0.67863695, 0.67923025, 0.67683222,
# ...

# %%
perform_apparent_model_evaluation('esr', 'TNFi', outcome_col = 'class_poor')
# Out:
# 2021-07-27 14:19:24,267;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: TNFi - outcome_col: class_poor - _type: log
# 2021-07-27 14:19:24,269;INFO - Created output directories
# 2021-07-27 14:23:01,467;INFO - {'acc_measure_values': array([0.15468   , 0.15472242, 0.15450722, 0.15462049, 0.15474553,
#        0.15467108, 0.15453167, 0.15464617, 0.15474927, 0.15485504,
#        0.15464903, 0.1550164 , 0.15496473, 0.15470799, 0.15485524,
#        0.15452193, 0.15494228, 0.15502374, 0.15491529, 0.15458203]), 'acc_measure': 0.15471520381808265, 'acc_measure_iqr': 0.00023050047988210087, 'auc_values': array([0.70686539, 0.70609137, 0.70806063, 0.707013  , 0.70564496,
#        0.70695899, 0.70783742, 0.70689779, 0.70635058, 0.70552975,
#        0.706995  , 0.70421932, 0.70401411, 0.70579976, 0.70554056,
# ...

# %%
perform_apparent_model_evaluation('crp', 'eta_ada', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-27 10:03:09,991;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: eta_ada - outcome_col: class - _type: mnlog
# 2021-07-27 10:03:10,007;INFO - Created output directories
# 2021-07-27 10:07:09,651;INFO - {'acc_measure_values': array([0.53026634, 0.53026634, 0.53026634, 0.53107345, 0.53188055,
#        0.53107345, 0.53107345, 0.53107345, 0.53107345, 0.52945924,
#        0.53026634, 0.53107345, 0.53026634, 0.53107345, 0.53026634,
#        0.53188055, 0.53026634, 0.53107345, 0.53026634, 0.52865214]), 'acc_measure': 0.5306698950766747, 'acc_measure_iqr': 0.0008071025020177647, 'auc_values': array([0.67241851, 0.67206297, 0.67296832, 0.67205019, 0.67208158,
#        0.67261674, 0.67278276, 0.67279085, 0.672757  , 0.6723552 ,
#        0.67241396, 0.67278056, 0.67266541, 0.67258164, 0.67225324,
# ...

# %%
perform_apparent_model_evaluation('esr', 'eta_ada', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-27 10:07:09,691;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: eta_ada - outcome_col: class - _type: mnlog
# 2021-07-27 10:07:09,693;INFO - Created output directories
# 2021-07-27 10:11:43,758;INFO - {'acc_measure_values': array([0.54848188, 0.54358472, 0.54554358, 0.54358472, 0.54456415,
#        0.54652302, 0.54554358, 0.54750245, 0.54652302, 0.54456415,
#        0.54652302, 0.54848188, 0.54652302, 0.54456415, 0.54358472,
#        0.54848188, 0.54162586, 0.54554358, 0.54848188, 0.54358472]), 'acc_measure': 0.545543584720862, 'acc_measure_iqr': 0.0024485798237021683, 'auc_values': array([0.69481568, 0.69391416, 0.69359572, 0.69411217, 0.69247012,
#        0.69361022, 0.69311891, 0.69261747, 0.69392583, 0.69420757,
#        0.69493041, 0.69347105, 0.69370353, 0.6933282 , 0.69185424,
# ...

# %%
perform_apparent_model_evaluation('crp', 'TNFi', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-27 14:23:01,491;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: TNFi - outcome_col: class - _type: mnlog
# 2021-07-27 14:23:01,503;INFO - Created output directories
# 2021-07-27 14:26:42,101;INFO - {'acc_measure_values': array([0.51875 , 0.518125, 0.51875 , 0.5175  , 0.52    , 0.52    ,
#        0.519375, 0.520625, 0.518125, 0.51875 , 0.51875 , 0.519375,
#        0.5175  , 0.518125, 0.518125, 0.51875 , 0.519375, 0.519375,
#        0.519375, 0.519375]), 'acc_measure': 0.51875, 'acc_measure_iqr': 0.0012500000000000844, 'auc_values': array([0.6695278 , 0.66928103, 0.6690355 , 0.66846705, 0.66870583,
#        0.66934179, 0.66965597, 0.66997013, 0.6687618 , 0.67035817,
#        0.66926048, 0.66885854, 0.66938876, 0.66939386, 0.66928898,
#        0.66883396, 0.66888529, 0.66948705, 0.66902384, 0.66970664]), 'auc': 0.6692850022237196, 'auc_iqr': 0.0006186342604649342, 'citls': array([[-0.45094108, -1.0423973 ],
#        [-0.4509889 , -1.04656287],
# ...

# %%
perform_apparent_model_evaluation('esr', 'TNFi', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-07-27 14:26:42,140;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: TNFi - outcome_col: class - _type: mnlog
# 2021-07-27 14:26:42,142;INFO - Created output directories
# 2021-07-27 14:30:28,037;INFO - {'acc_measure_values': array([0.52644041, 0.52565114, 0.52644041, 0.52801894, 0.52407261,
#        0.52644041, 0.52880821, 0.52644041, 0.52565114, 0.52565114,
#        0.52722968, 0.52722968, 0.52565114, 0.52722968, 0.52486188,
#        0.52407261, 0.52722968, 0.52644041, 0.52722968, 0.52959747]), 'acc_measure': 0.526440410418311, 'acc_measure_iqr': 0.0015785319652722452, 'auc_values': array([0.69029007, 0.68915844, 0.68883924, 0.69022669, 0.68902164,
#        0.69043053, 0.69048777, 0.69070836, 0.68883401, 0.6883616 ,
#        0.69010515, 0.69026789, 0.68835071, 0.6885961 , 0.69070029,
#        0.68842442, 0.69034656, 0.68862069, 0.68828371, 0.69051019]), 'auc': 0.6896317946251687, 'auc_iqr': 0.0017530137809163016, 'citls': array([[-0.45244813, -1.07032831],
# ...

# %%
perform_apparent_model_evaluation('crp', 'etanercept', outcome_col = '2cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('crp', 'adalimumab', outcome_col = '2cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('crp', 'eta_ada', outcome_col = '2cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('crp', 'TNFi', outcome_col = '2cdas_fu', _type = 'cont')
# Out:
# 2021-08-15 22:41:13,205;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: etanercept - outcome_col: 2cdas_fu - _type: cont
# 2021-08-15 22:41:13,212;INFO - Created output directories
# 2021-08-15 22:44:42,950;INFO - {'mse_values': array([2.19310743, 2.19148272, 2.19875924, 2.19850586, 2.19492769,
#        2.18887458, 2.19271088, 2.19914902, 2.18952609, 2.19638257,
#        2.20248212, 2.19737658, 2.20199616, 2.19518161, 2.19429237,
#        2.1910193 , 2.1932027 , 2.19965715, 2.19659812, 2.19795821]), 'mse': 2.1957820924108207, 'mse_values_iqr': 0.005560914094921987, 'mae_values': array([1.20225782, 1.20182337, 1.20349983, 1.20302762, 1.2028066 ,
#        1.20065234, 1.20133399, 1.20370958, 1.20103313, 1.20261338,
#        1.20446795, 1.20270669, 1.20453248, 1.20292194, 1.20210375,
# ...

# %%
perform_apparent_model_evaluation('esr', 'etanercept', outcome_col = '2cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'adalimumab', outcome_col = '2cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'eta_ada', outcome_col = '2cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'TNFi', outcome_col = '2cdas_fu', _type = 'cont')
# Out:
# 2021-08-15 22:55:39,109;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: etanercept - outcome_col: 2cdas_fu - _type: cont
# 2021-08-15 22:55:39,114;INFO - Created output directories
# 2021-08-15 22:58:58,791;INFO - {'mse_values': array([1.80587494, 1.80299517, 1.81035128, 1.80209023, 1.80503614,
#        1.8101008 , 1.81121732, 1.80342133, 1.81244275, 1.80611746,
#        1.80464513, 1.80302748, 1.80369252, 1.81147963, 1.80311557,
#        1.80377183, 1.81033825, 1.80048048, 1.80483091, 1.80376697]), 'mse': 1.8047380200625285, 'mse_values_iqr': 0.0068152713476499205, 'mae_values': array([1.08376113, 1.08279536, 1.08498709, 1.08262229, 1.08395882,
#        1.0848606 , 1.0849606 , 1.08248249, 1.08542096, 1.08427734,
#        1.08325429, 1.08248782, 1.08297687, 1.08507725, 1.08267464,
# ...

# %%
perform_apparent_model_evaluation('crp', 'etanercept', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('crp', 'adalimumab', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'etanercept', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'adalimumab', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('crp', 'eta_ada', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'eta_ada', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('crp', 'TNFi', outcome_col = '4cdas_fu', _type = 'cont')
perform_apparent_model_evaluation('esr', 'TNFi', outcome_col = '4cdas_fu', _type = 'cont')
# Out:
# 2021-08-13 18:28:38,197;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: etanercept - outcome_col: 4cdas_fu - _type: cont
# 2021-08-13 18:28:38,218;INFO - Created output directories
# 2021-08-13 18:31:52,469;INFO - {'mse_values': array([1.56908995, 1.5767306 , 1.57013694, 1.57657131, 1.57518434,
#        1.57676593, 1.57134387, 1.57437871, 1.57201738, 1.57134151,
#        1.57605763, 1.57618187, 1.5738766 , 1.57897463, 1.56645651,
#        1.56961494, 1.5765259 , 1.56786184, 1.57410793, 1.56967579]), 'mse': 1.5739922615158775, 'mse_values_iqr': 0.0062462244554275514, 'mae_values': array([1.02824113, 1.03159842, 1.02916351, 1.03109952, 1.03068952,
#        1.03117269, 1.02947443, 1.0303613 , 1.02987028, 1.02953141,
#        1.03118093, 1.03099907, 1.03022046, 1.03247942, 1.02777726,
# ...
