# %%
from model_evaluation import perform_apparent_model_evaluation

# %%
perform_apparent_model_evaluation('esr', 'adalimumab')
# Out:
# 2021-03-12 12:53:05,585;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: adalimumab - outcome_col: class_bin - _type: log
# 2021-03-12 12:53:05,597;INFO - Created output directories
# 2021-03-12 12:57:57,910;INFO - {'acc_measure_values': array([0.19936067, 0.19592474, 0.19949739, 0.19649831, 0.1955375 ,
#        0.19551491, 0.19584607, 0.19933718, 0.199801  , 0.19560133,
#        0.19533613, 0.19558981, 0.19602058, 0.19568152, 0.19974523,
#        0.20000407, 0.1956794 , 0.19563397, 0.19911298, 0.19516295]), 'acc_measure': 0.19588540370792473, 'acc_measure_iqr': 0.0037446000547707303, 'auc_values': array([0.75786035, 0.7680686 , 0.75786035, 0.76725194, 0.7694297 ,
#        0.76902137, 0.76902137, 0.75799646, 0.75677147, 0.76929359,
#        0.77024636, 0.76929359, 0.76738805, 0.76915748, 0.75745202,
# ...

# %%
perform_apparent_model_evaluation('crp', 'adalimumab')
# Out:
# 2021-03-12 12:57:57,942;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: adalimumab - outcome_col: class_bin - _type: log
# 2021-03-12 12:57:57,944;INFO - Created output directories
# 2021-03-12 13:03:16,582;INFO - {'acc_measure_values': array([0.21686925, 0.21584913, 0.21580955, 0.21640452, 0.21539404,
#        0.21659325, 0.21531835, 0.21615096, 0.21670527, 0.21649207,
#        0.21682447, 0.21579142, 0.21566759, 0.21598061, 0.21670133,
#        0.21563149, 0.21578925, 0.2164363 , 0.21564249, 0.21566399]), 'acc_measure': 0.2159148675586064, 'acc_measure_iqr': 0.0008506779866352121, 'auc_values': array([0.71227723, 0.71574257, 0.71524752, 0.71257426, 0.71623762,
#        0.71326733, 0.71712871, 0.71455446, 0.71277228, 0.71287129,
#        0.71227723, 0.71653465, 0.71514851, 0.7149505 , 0.71287129,
# ...

# %%
perform_apparent_model_evaluation('esr', 'etanercept')
# Out:
# 2021-03-12 13:03:16,607;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: etanercept - outcome_col: class_bin - _type: log
# 2021-03-12 13:03:16,613;INFO - Created output directories
# 2021-03-12 13:06:51,797;INFO - {'acc_measure_values': array([0.21729238, 0.21487713, 0.21521825, 0.21723018, 0.21540469,
#        0.21722884, 0.21743315, 0.21528535, 0.21511845, 0.21525714,
#        0.21730329, 0.21733806, 0.21520823, 0.21504885, 0.21490183,
#        0.21515155, 0.21491685, 0.21527903, 0.21700375, 0.21751251]), 'acc_measure': 0.21528218882197003, 'acc_measure_iqr': 0.00210245539251655, 'auc_values': array([0.70346384, 0.71061188, 0.70951012, 0.70381318, 0.70832773,
#        0.70362508, 0.70295327, 0.70862333, 0.7097251 , 0.70875769,
#        0.7031145 , 0.70308763, 0.70929514, 0.70967135, 0.71053127,
# ...

# %%
perform_apparent_model_evaluation('crp', 'etanercept')
# Out:
# 2021-03-12 13:06:51,833;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: etanercept - outcome_col: class_bin - _type: log
# 2021-03-12 13:06:51,836;INFO - Created output directories
# 2021-03-12 13:10:47,996;INFO - {'acc_measure_values': array([0.22073354, 0.21963676, 0.2208254 , 0.2197357 , 0.21977951,
#        0.22090118, 0.2210642 , 0.21977426, 0.22033463, 0.21956562,
#        0.21930686, 0.22104412, 0.22019308, 0.21924138, 0.2210347 ,
#        0.22121417, 0.21945251, 0.21929838, 0.21988253, 0.22089514]), 'acc_measure': 0.22003780558546593, 'acc_measure_iqr': 0.001277676984120929, 'auc_values': array([0.70043155, 0.70372741, 0.70050268, 0.70337175, 0.70325319,
#        0.69988619, 0.69960165, 0.70334803, 0.70209134, 0.70403566,
#        0.70462844, 0.69962536, 0.70235216, 0.70515009, 0.69962536,
# ...

# %%
perform_apparent_model_evaluation('crp', 'adalimumab', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-03-10 18:34:38,675;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: adalimumab - outcome_col: class - _type: mnlog
# 2021-03-10 18:34:38,682;INFO - Created output directories
# 2021-03-10 18:39:39,309;INFO - {'acc_measure_values': array([0.60199005, 0.5920398 , 0.59701493, 0.59701493, 0.59701493,
#        0.5920398 , 0.59701493, 0.5920398 , 0.60199005, 0.5920398 ,
#        0.60199005, 0.58706468, 0.59701493, 0.59701493, 0.59701493,
#        0.5920398 , 0.59701493, 0.58706468, 0.60199005, 0.59701493]), 'acc_measure': 0.5970149253731343, 'acc_measure_iqr': 0.00497512437810943, 'auc_values': array([0.7312392 , 0.73027503, 0.73239981, 0.72806066, 0.73235974,
#        0.73145293, 0.73276678, 0.73123605, 0.73319032, 0.72821154,
#        0.73154408, 0.73050605, 0.72888732, 0.72834591, 0.73200299,
# ...

# %%
perform_apparent_model_evaluation('esr', 'adalimumab', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-03-10 19:19:01,105;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: adalimumab - outcome_col: class - _type: mnlog
# 2021-03-10 19:19:01,114;INFO - Created output directories
# 2021-03-10 19:23:37,196;INFO - {'acc_measure_values': array([0.63372093, 0.62209302, 0.62790698, 0.62209302, 0.61627907,
#        0.62790698, 0.62790698, 0.61627907, 0.62209302, 0.62209302,
#        0.62209302, 0.62790698, 0.62209302, 0.62790698, 0.61627907,
#        0.62790698, 0.61627907, 0.62209302, 0.62209302, 0.62209302]), 'acc_measure': 0.622093023255814, 'acc_measure_iqr': 0.005813953488372103, 'auc_values': array([0.78305204, 0.77462624, 0.78200903, 0.77435276, 0.77326476,
#        0.78142892, 0.77602679, 0.77424858, 0.77342932, 0.77429949,
#        0.77381527, 0.78218424, 0.77273556, 0.77578173, 0.78160177,
# ...

# %%
perform_apparent_model_evaluation('crp', 'etanercept', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-03-10 19:23:37,254;INFO - perform_apparent_model_evaluation: das_type: crp - treatment: etanercept - outcome_col: class - _type: mnlog
# 2021-03-10 19:23:37,269;INFO - Created output directories
# 2021-03-10 19:27:12,374;INFO - {'acc_measure_values': array([0.57664234, 0.57664234, 0.57177616, 0.57664234, 0.56934307,
#        0.57177616, 0.56934307, 0.57420925, 0.57664234, 0.57664234,
#        0.56934307, 0.56934307, 0.57177616, 0.57664234, 0.57177616,
#        0.57664234, 0.57664234, 0.57177616, 0.57664234, 0.57664234]), 'acc_measure': 0.5754257907542579, 'acc_measure_iqr': 0.0048661800486617945, 'auc_values': array([0.6890897 , 0.68863356, 0.69336915, 0.68902238, 0.6921088 ,
#        0.69347964, 0.69287557, 0.68801712, 0.68805304, 0.68926419,
#        0.69241279, 0.69241551, 0.69337549, 0.68683345, 0.69338666,
# ...

# %%
perform_apparent_model_evaluation('esr', 'etanercept', outcome_col = 'class', _type = 'mnlog')
# Out:
# 2021-03-10 19:27:12,421;INFO - perform_apparent_model_evaluation: das_type: esr - treatment: etanercept - outcome_col: class - _type: mnlog
# 2021-03-10 19:27:12,423;INFO - Created output directories
# 2021-03-10 19:31:00,134;INFO - {'acc_measure_values': array([0.55181347, 0.55440415, 0.55699482, 0.55181347, 0.55181347,
#        0.55440415, 0.5492228 , 0.5492228 , 0.55440415, 0.55181347,
#        0.55181347, 0.55181347, 0.55440415, 0.55440415, 0.55181347,
#        0.55440415, 0.5492228 , 0.55181347, 0.55181347, 0.55440415]), 'acc_measure': 0.5518134715025906, 'acc_measure_iqr': 0.002590673575129543, 'auc_values': array([0.69412043, 0.69830969, 0.69811456, 0.69835458, 0.69351588,
#        0.69524551, 0.69838707, 0.69830756, 0.69548116, 0.6949605 ,
#        0.69445652, 0.69496456, 0.69378893, 0.69793481, 0.69344674,
# ...
